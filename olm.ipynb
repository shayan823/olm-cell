# %%
#!pip install pyneuroml neuromllite NEURON

# %%
from neuroml import (NeuroMLDocument, IncludeType, Population, PulseGenerator, ExplicitInput, Network, SegmentGroup, Member, Property, Include, Instance, Location)
from CellBuilder import (create_cell, add_segment, add_channel_density, set_init_memb_potential, set_resistivity, set_specific_capacitance, get_seg_group_by_id)
from pyneuroml import pynml
from pyneuroml.lems import LEMSSimulation
import numpy as np

# %%
def create_olm_cell():
    """Create the complete cell.

    :returns: cell object
    """
    nml_cell_doc = NeuroMLDocument(id="oml_cell")
    cell = create_cell("olm")
    nml_cell_file = cell.id + ".cell.nml"

    # Add two soma segments
    diam = 10.0
    soma_0 = add_segment(cell,
                         prox=[0.0, 0.0, 0.0, diam],
                         dist=[0.0, 10., 0.0, diam],
                         name="Seg0_soma_0",
                         group="soma_0")

    soma_1 = add_segment(cell,
                         prox=None,
                         dist=[0.0, 10. + 10., 0.0, diam],
                         name="Seg1_soma_0",
                         parent=soma_0,
                         group="soma_0")

    # Add axon segments
    diam = 1.5
    axon_0 = add_segment(cell,
                         prox=[0.0, 0.0, 0.0, diam],
                         dist=[0.0, -75, 0.0, diam],
                         name="Seg0_axon_0",
                         parent=soma_0,
                         fraction_along=0.0,
                         group="axon_0")
    axon_1 = add_segment(cell,
                         prox=None,
                         dist=[0.0, -150, 0.0, diam],
                         name="Seg1_axon_0",
                         parent=axon_0,
                         group="axon_0")

    # Add 2 dendrite segments

    diam = 3.0
    dend_0_0 = add_segment(cell,
                           prox=[0.0, 20, 0.0, diam],
                           dist=[100, 120, 0.0, diam],
                           name="Seg0_dend_0",
                           parent=soma_1,
                           fraction_along=1,
                           group="dend_0")

    dend_1_0 = add_segment(cell,
                           prox=None,
                           dist=[177, 197, 0.0, diam],
                           name="Seg1_dend_0",
                           parent=dend_0_0,
                           fraction_along=1,
                           group="dend_0")

    dend_0_1 = add_segment(cell,
                           prox=[0.0, 20, 0.0, diam],
                           dist=[-100, 120, 0.0, diam],
                           name="Seg0_dend_1",
                           parent=soma_1,
                           fraction_along=1,
                           group="dend_1")
    dend_1_1 = add_segment(cell,
                           prox=None,
                           dist=[-177, 197, 0.0, diam],
                           name="Seg1_dend_1",
                           parent=dend_0_1,
                           fraction_along=1,
                           group="dend_1")

    # XXX: For segment groups to be correctly mapped to sections in NEURON,
    # they must include the correct neurolex ID
    for section_name in ["soma_0", "axon_0", "dend_0", "dend_1"]:
        section_group = get_seg_group_by_id(section_name, cell)
        section_group.neuro_lex_id = 'sao864921383'

    den_seg_group = get_seg_group_by_id("dendrite_group", cell)
    den_seg_group.includes.append(Include(segment_groups="dend_0"))
    den_seg_group.includes.append(Include(segment_groups="dend_1"))
    den_seg_group.properties.append(Property(tag="color", value="0.8 0 0"))

    ax_seg_group = get_seg_group_by_id("axon_group", cell)
    ax_seg_group.includes.append(Include(segment_groups="axon_0"))
    ax_seg_group.properties.append(Property(tag="color", value="0 0.8 0"))

    soma_seg_group = get_seg_group_by_id("soma_group", cell)
    soma_seg_group.includes.append(Include(segment_groups="soma_0"))

    soma_seg_group.properties.append(Property(tag="color", value="0 0 0.8"))

    # Other cell properties
    set_init_memb_potential(cell, "-67mV")
    set_resistivity(cell, "0.15 kohm_cm")
    set_specific_capacitance(cell, "1.3 uF_per_cm2")

    # channels
    # leak
    add_channel_density(cell, nml_cell_doc,
                        cd_id="leak_all",
                        cond_density="0.01 mS_per_cm2",
                        ion_channel="leak_chan",
                        ion_chan_def_file="olm-example/leak_chan.channel.nml",
                        erev="-67mV",
                        ion="non_specific")
    # HCNolm_soma
    add_channel_density(cell, nml_cell_doc,
                        cd_id="HCNolm_soma",
                        cond_density="0.5 mS_per_cm2",
                        ion_channel="HCNolm",
                        ion_chan_def_file="olm-example/HCNolm.channel.nml",
                        erev="-32.9mV",
                        ion="h",
                        group="soma_group")
    # Kdrfast_soma
    add_channel_density(cell, nml_cell_doc,
                        cd_id="Kdrfast_soma",
                        cond_density="73.37 mS_per_cm2",
                        ion_channel="Kdrfast",
                        ion_chan_def_file="olm-example/Kdrfast.channel.nml",
                        erev="-77mV",
                        ion="k",
                        group="soma_group")
    # Kdrfast_dendrite
    add_channel_density(cell, nml_cell_doc,
                        cd_id="Kdrfast_dendrite",
                        cond_density="105.8 mS_per_cm2",
                        ion_channel="Kdrfast",
                        ion_chan_def_file="olm-example/Kdrfast.channel.nml",
                        erev="-77mV",
                        ion="k",
                        group="dendrite_group")
    # Kdrfast_axon
    add_channel_density(cell, nml_cell_doc,
                        cd_id="Kdrfast_axon",
                        cond_density="117.392 mS_per_cm2",
                        ion_channel="Kdrfast",
                        ion_chan_def_file="olm-example/Kdrfast.channel.nml",
                        erev="-77mV",
                        ion="k",
                        group="axon_group")
    # KvAolm_soma
    add_channel_density(cell, nml_cell_doc,
                        cd_id="KvAolm_soma",
                        cond_density="4.95 mS_per_cm2",
                        ion_channel="KvAolm",
                        ion_chan_def_file="olm-example/KvAolm.channel.nml",
                        erev="-77mV",
                        ion="k",
                        group="soma_group")
    # KvAolm_dendrite
    add_channel_density(cell, nml_cell_doc,
                        cd_id="KvAolm_dendrite",
                        cond_density="2.8 mS_per_cm2",
                        ion_channel="KvAolm",
                        ion_chan_def_file="olm-example/KvAolm.channel.nml",
                        erev="-77mV",
                        ion="k",
                        group="dendrite_group")
    # Nav_soma
    add_channel_density(cell, nml_cell_doc,
                        cd_id="Nav_soma",
                        cond_density="10.7 mS_per_cm2",
                        ion_channel="Nav",
                        ion_chan_def_file="olm-example/Nav.channel.nml",
                        erev="50mV",
                        ion="na",
                        group="soma_group")
    # Nav_dendrite
    add_channel_density(cell, nml_cell_doc,
                        cd_id="Nav_dendrite",
                        cond_density="23.4 mS_per_cm2",
                        ion_channel="Nav",
                        ion_chan_def_file="olm-example/Nav.channel.nml",
                        erev="50mV",
                        ion="na",
                        group="dendrite_group")
    # Nav_axon
    add_channel_density(cell, nml_cell_doc,
                        cd_id="Nav_axon",
                        cond_density="17.12 mS_per_cm2",
                        ion_channel="Nav",
                        ion_chan_def_file="olm-example/Nav.channel.nml",
                        erev="50mV",
                        ion="na",
                        group="axon_group")

    nml_cell_doc.cells.append(cell)
    pynml.write_neuroml2_file(nml_cell_doc, nml_cell_file, True, True)
    return nml_cell_file

# %%
def create_olm_network():
    """Create the network

    :returns: name of network nml file
    """
    net_doc = NeuroMLDocument(id="network",
                              notes="OLM cell network")
    net_doc_fn = "olm_example_net.nml"
    net_doc.includes.append(IncludeType(href=create_olm_cell()))
    # Create a population: convenient to create many cells of the same type
    pop = Population(id="pop0", notes="A population for our cell",
                     component="olm", size=1, type="populationList")
    pop.instances.append(Instance(id=1, location=Location(0., 0., 0.)))
    # Input
    pulsegen = PulseGenerator(id="pg_olm", notes="Simple pulse generator", delay="100ms", duration="100ms", amplitude="0.08nA")

    exp_input = ExplicitInput(target="pop0[0]", input="pg_olm")

    net = Network(id="single_olm_cell_network", note="A network with a single population")
    net_doc.pulse_generators.append(pulsegen)
    net.explicit_inputs.append(exp_input)
    net.populations.append(pop)
    net_doc.networks.append(net)

    pynml.write_neuroml2_file(nml2_doc=net_doc, nml2_file_name=net_doc_fn, validate=True)
    return net_doc_fn

# %%
def plot_data(sim_id):
    """Plot the sim data.

    Load the data from the file and plot the graph for the membrane potential
    using the pynml generate_plot utility function.

    :sim_id: ID of simulaton

    """
    data_array = np.loadtxt(sim_id + ".dat")
    pynml.generate_plot([data_array[:, 0]], [data_array[:, 1]], "Membrane potential (soma seg 0)", show_plot_already=False, save_figure_to=sim_id + "_seg0_soma0-v.png", xaxis="time (s)", yaxis="membrane potential (V)")
    pynml.generate_plot([data_array[:, 0]], [data_array[:, 2]], "Membrane potential (soma seg 1)", show_plot_already=False, save_figure_to=sim_id + "_seg1_soma0-v.png", xaxis="time (s)", yaxis="membrane potential (V)")
    pynml.generate_plot([data_array[:, 0]], [data_array[:, 3]], "Membrane potential (axon seg 0)", show_plot_already=False, save_figure_to=sim_id + "_seg0_axon0-v.png", xaxis="time (s)", yaxis="membrane potential (V)")
    pynml.generate_plot([data_array[:, 0]], [data_array[:, 4]], "Membrane potential (axon seg 1)", show_plot_already=False, save_figure_to=sim_id + "_seg1_axon0-v.png", xaxis="time (s)", yaxis="membrane potential (V)")

# %%
def main():
    """Main function

    Include the NeuroML model into a LEMS simulation file, run it, plot some
    data.
    """
    # Simulation bits
    sim_id = "olm_example_sim"
    simulation = LEMSSimulation(sim_id=sim_id, duration=600, dt=0.01, simulation_seed=123)
    # Include the NeuroML model file
    simulation.include_neuroml2_file(create_olm_network())
    # Assign target for the simulation
    simulation.assign_simulation_target("single_olm_cell_network")
    print("create output columns")
    # Recording information from the simulation
    simulation.create_output_file(id="output0", file_name=sim_id + ".dat")
    simulation.add_column_to_output_file("output0", column_id="pop0_0_v", quantity="pop0[0]/v")
    simulation.add_column_to_output_file("output0",
                                         column_id="pop0_0_v_Seg0_soma_0",
                                         quantity="pop0/0/olm/0/v")
    simulation.add_column_to_output_file("output0",
                                         column_id="pop0_0_v_Seg1_soma_0",
                                         quantity="pop0/0/olm/1/v")
    simulation.add_column_to_output_file("output0",
                                         column_id="pop0_0_v_Seg0_axon_0",
                                         quantity="pop0/0/olm/2/v")
    simulation.add_column_to_output_file("output0",
                                         column_id="pop0_0_v_Seg1_axon_0",
                                         quantity="pop0/0/olm/3/v")
    simulation.add_column_to_output_file("output0",
                                         column_id="pop0_0_v_Seg0_dend_0",
                                         quantity="pop0/0/olm/4/v")
    simulation.add_column_to_output_file("output0",
                                         column_id="pop0_0_v_Seg1_dend_0",
                                         quantity="pop0/0/olm/6/v")
    simulation.add_column_to_output_file("output0",
                                         column_id="pop0_0_v_Seg0_dend_1",
                                         quantity="pop0/0/olm/5/v")
    simulation.add_column_to_output_file("output0",
                                         column_id="pop0_0_v_Seg1_dend_1",
                                         quantity="pop0/0/olm/7/v")
    # Save LEMS simulation to file
    sim_file = simulation.save_to_file()
    print("simulation saved")
    # Run the simulation using the NEURON simulator
    pynml.run_lems_with_jneuroml_neuron(sim_file, max_memory="2G", nogui=True,
                                        plot=False, skip_run=False)
    print("lems done")
    # Plot the data
    plot_data(sim_id)

# %%
if __name__ == "__main__":
    main()
# Out:
# pyNeuroML >>> INFO - Executing: (java -Xmx400M  -jar  "/Users/shayan/opt/anaconda3/lib/python3.9/site-packages/pyneuroml/lib/jNeuroML-0.11.1-jar-with-dependencies.jar" -validate "olm.cell.nml" ) in directory: .
# pyNeuroML >>> INFO - Command completed. Output:
#   jNeuroML >>   jNeuroML v0.11.1
#   jNeuroML >>  Validating: /Users/shayan/Desktop/CN/gsoc_cn/olm_multicompartmental/olm.cell.nml
#   jNeuroML >>  Valid against schema and all tests
#   jNeuroML >>
#   jNeuroML >>    Warning, check: 100005 (Segment Group used in the include element of segmentGroup should probably be defined BEFORE it is used in the segmentGroup in which it is included, for optimal portability) failed! ... SegmentGroup: soma_group, includes: soma_0
#   jNeuroML >>    Warning, check: 100005 (Segment Group used in the include element of segmentGroup should probably be defined BEFORE it is used in the segmentGroup in which it is included, for optimal portability) failed! ... SegmentGroup: axon_group, includes: axon_0
#   jNeuroML >>    Warning, check: 100005 (Segment Group used in the include element of segmentGroup should probably be defined BEFORE it is used in the segmentGroup in which it is included, for optimal portability) failed! ... SegmentGroup: dendrite_group, includes: dend_0
#   jNeuroML >>    Warning, check: 100005 (Segment Group used in the include element of segmentGroup should probably be defined BEFORE it is used in the segmentGroup in which it is included, for optimal portability) failed! ... SegmentGroup: dendrite_group, includes: dend_1
#   jNeuroML >>
#   jNeuroML >>  Validated 1 files: 0 passed, 1 passed with warnings,
#   jNeuroML >>
#   jNeuroML >>
# pyNeuroML >>> INFO - Executing: (java -Xmx400M  -jar  "/Users/shayan/opt/anaconda3/lib/python3.9/site-packages/pyneuroml/lib/jNeuroML-0.11.1-jar-with-dependencies.jar" -validate "olm_example_net.nml" ) in directory: .
# pyNeuroML >>> INFO - Command completed. Output:
#   jNeuroML >>   jNeuroML v0.11.1
#   jNeuroML >>  Validating: /Users/shayan/Desktop/CN/gsoc_cn/olm_multicompartmental/olm_example_net.nml
#   jNeuroML >>  Valid against schema and all tests
#   jNeuroML >>
#   jNeuroML >>    Warning, check: 100005 (Segment Group used in the include element of segmentGroup should probably be defined BEFORE it is used in the segmentGroup in which it is included, for optimal portability) failed! ... SegmentGroup: soma_group, includes: soma_0
#   jNeuroML >>    Warning, check: 100005 (Segment Group used in the include element of segmentGroup should probably be defined BEFORE it is used in the segmentGroup in which it is included, for optimal portability) failed! ... SegmentGroup: axon_group, includes: axon_0
#   jNeuroML >>    Warning, check: 100005 (Segment Group used in the include element of segmentGroup should probably be defined BEFORE it is used in the segmentGroup in which it is included, for optimal portability) failed! ... SegmentGroup: dendrite_group, includes: dend_0
#   jNeuroML >>    Warning, check: 100005 (Segment Group used in the include element of segmentGroup should probably be defined BEFORE it is used in the segmentGroup in which it is included, for optimal portability) failed! ... SegmentGroup: dendrite_group, includes: dend_1
#   jNeuroML >>
#   jNeuroML >>  Validated 1 files: 0 passed, 1 passed with warnings,
#   jNeuroML >>
#   jNeuroML >>
# pyNeuroML >>> INFO - Loading NeuroML2 file: /Users/shayan/Desktop/CN/gsoc_cn/olm_multicompartmental/olm_example_net.nml
# pyNeuroML >>> INFO - Loading NeuroML2 file: /Users/shayan/Desktop/CN/gsoc_cn/olm_multicompartmental/olm.cell.nml
# pyNeuroML >>> INFO - Loading NeuroML2 file: /Users/shayan/Desktop/CN/gsoc_cn/olm_multicompartmental/olm-example/leak_chan.channel.nml
# pyNeuroML >>> INFO - Loading NeuroML2 file: /Users/shayan/Desktop/CN/gsoc_cn/olm_multicompartmental/olm-example/HCNolm.channel.nml
# pyNeuroML >>> INFO - Loading NeuroML2 file: /Users/shayan/Desktop/CN/gsoc_cn/olm_multicompartmental/olm-example/Kdrfast.channel.nml
# pyNeuroML >>> INFO - Loading NeuroML2 file: /Users/shayan/Desktop/CN/gsoc_cn/olm_multicompartmental/olm-example/KvAolm.channel.nml
# pyNeuroML >>> INFO - Loading NeuroML2 file: /Users/shayan/Desktop/CN/gsoc_cn/olm_multicompartmental/olm-example/Nav.channel.nml
# pyNeuroML >>> INFO - Loading LEMS file: LEMS_olm_example_sim.xml and running with jNeuroML_NEURON
# pyNeuroML >>> INFO - Executing: (java -Xmx2G  -Djava.awt.headless=true -jar  "/Users/shayan/opt/anaconda3/lib/python3.9/site-packages/pyneuroml/lib/jNeuroML-0.11.1-jar-with-dependencies.jar"  "LEMS_olm_example_sim.xml"  -neuron -run -compile -nogui -I '') in directory: .
# <?xml version="1.0" ?>
# <neuroml xmlns:xs="http://www.w3.org/2001/XMLSchema" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" id="network">
#     <notes>OLM cell network</notes>
#     <include href="olm.cell.nml"/>
#     <pulseGenerator id="pg_olm" delay="100ms" duration="100ms" amplitude="0.08nA">
#         <notes>Simple pulse generator</notes>
#     </pulseGenerator>
#     <network id="single_olm_cell_network">
#         <population id="pop0" component="olm" size="1" type="populationList">
#             <notes>A population for our cell</notes>
#             <instance id="1">
#                 <location x="0." y="0." z="0."/>
#             </instance>
#         </population>
#         <explicitInput target="pop0[0]" input="pg_olm"/>
#     </network>
# </neuroml>
# <?xml version="1.0" ?>
# <neuroml xmlns:xs="http://www.w3.org/2001/XMLSchema" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" id="oml_cell">
#     <include href="olm-example/leak_chan.channel.nml"/>
#     <include href="olm-example/HCNolm.channel.nml"/>
#     <include href="olm-example/Kdrfast.channel.nml"/>
#     <include href="olm-example/KvAolm.channel.nml"/>
#     <include href="olm-example/Nav.channel.nml"/>
#     <cell id="olm">
#         <morphology id="morphology">
#             <segment id="0" name="Seg0_soma_0">
#                 <proximal x="0.0" y="0.0" z="0.0" diameter="10.0"/>
#                 <distal x="0.0" y="10.0" z="0.0" diameter="10.0"/>
#             </segment>
#             <segment id="1" name="Seg1_soma_0">
#                 <parent segment="0"/>
#                 <distal x="0.0" y="20.0" z="0.0" diameter="10.0"/>
#             </segment>
#             <segment id="2" name="Seg0_axon_0">
#                 <parent segment="0" fractionAlong="0."/>
#                 <proximal x="0.0" y="0.0" z="0.0" diameter="1.5"/>
#                 <distal x="0.0" y="-75.0" z="0.0" diameter="1.5"/>
#             </segment>
#             <segment id="3" name="Seg1_axon_0">
#                 <parent segment="2"/>
#                 <distal x="0.0" y="-150.0" z="0.0" diameter="1.5"/>
#             </segment>
#             <segment id="4" name="Seg0_dend_0">
#                 <parent segment="1"/>
#                 <proximal x="0.0" y="20.0" z="0.0" diameter="3.0"/>
#                 <distal x="100.0" y="120.0" z="0.0" diameter="3.0"/>
#             </segment>
#             <segment id="5" name="Seg1_dend_0">
#                 <parent segment="4"/>
#                 <distal x="177.0" y="197.0" z="0.0" diameter="3.0"/>
#             </segment>
#             <segment id="6" name="Seg0_dend_1">
#                 <parent segment="1"/>
#                 <proximal x="0.0" y="20.0" z="0.0" diameter="3.0"/>
#                 <distal x="-100.0" y="120.0" z="0.0" diameter="3.0"/>
#             </segment>
#             <segment id="7" name="Seg1_dend_1">
#                 <parent segment="6"/>
#                 <distal x="-177.0" y="197.0" z="0.0" diameter="3.0"/>
#             </segment>
#             <segmentGroup id="all">
#                 <member segment="0"/>
#                 <member segment="1"/>
#                 <member segment="2"/>
#                 <member segment="3"/>
#                 <member segment="4"/>
#                 <member segment="5"/>
#                 <member segment="6"/>
#                 <member segment="7"/>
#             </segmentGroup>
#             <segmentGroup neuroLexId="GO:0043025" id="soma_group">
#                 <notes>Default soma segment group for the cell</notes>
#                 <property tag="color" value="0 0 0.8"/>
#                 <member segment="0"/>
#                 <member segment="1"/>
#                 <include segmentGroup="soma_0"/>
#             </segmentGroup>
#             <segmentGroup neuroLexId="GO:0030424" id="axon_group">
#                 <notes>Default axon segment group for the cell</notes>
#                 <property tag="color" value="0 0.8 0"/>
#                 <member segment="2"/>
#                 <member segment="3"/>
#                 <include segmentGroup="axon_0"/>
#             </segmentGroup>
#             <segmentGroup neuroLexId="GO:0030425" id="dendrite_group">
#                 <notes>Default dendrite segment group for the cell</notes>
#                 <property tag="color" value="0.8 0 0"/>
#                 <member segment="4"/>
#                 <member segment="5"/>
#                 <member segment="6"/>
#                 <member segment="7"/>
#                 <include segmentGroup="dend_0"/>
#                 <include segmentGroup="dend_1"/>
#             </segmentGroup>
#             <segmentGroup neuroLexId="sao864921383" id="soma_0">
#                 <member segment="0"/>
#                 <member segment="1"/>
#             </segmentGroup>
#             <segmentGroup neuroLexId="sao864921383" id="axon_0">
#                 <member segment="2"/>
#                 <member segment="3"/>
#             </segmentGroup>
#             <segmentGroup neuroLexId="sao864921383" id="dend_0">
#                 <member segment="4"/>
#                 <member segment="5"/>
#             </segmentGroup>
#             <segmentGroup neuroLexId="sao864921383" id="dend_1">
#                 <member segment="6"/>
#                 <member segment="7"/>
#             </segmentGroup>
#         </morphology>
#         <biophysicalProperties id="biophys">
#             <membraneProperties>
#                 <channelDensity id="leak_all" ionChannel="leak_chan" condDensity="0.01 mS_per_cm2" erev="-67mV" ion="non_specific"/>
#                 <channelDensity id="HCNolm_soma" ionChannel="HCNolm" condDensity="0.5 mS_per_cm2" erev="-32.9mV" segmentGroup="soma_group" ion="h"/>
#                 <channelDensity id="Kdrfast_soma" ionChannel="Kdrfast" condDensity="73.37 mS_per_cm2" erev="-77mV" segmentGroup="soma_group" ion="k"/>
#                 <channelDensity id="Kdrfast_dendrite" ionChannel="Kdrfast" condDensity="105.8 mS_per_cm2" erev="-77mV" segmentGroup="dendrite_group" ion="k"/>
#                 <channelDensity id="Kdrfast_axon" ionChannel="Kdrfast" condDensity="117.392 mS_per_cm2" erev="-77mV" segmentGroup="axon_group" ion="k"/>
#                 <channelDensity id="KvAolm_soma" ionChannel="KvAolm" condDensity="4.95 mS_per_cm2" erev="-77mV" segmentGroup="soma_group" ion="k"/>
#                 <channelDensity id="KvAolm_dendrite" ionChannel="KvAolm" condDensity="2.8 mS_per_cm2" erev="-77mV" segmentGroup="dendrite_group" ion="k"/>
#                 <channelDensity id="Nav_soma" ionChannel="Nav" condDensity="10.7 mS_per_cm2" erev="50mV" segmentGroup="soma_group" ion="na"/>
#                 <channelDensity id="Nav_dendrite" ionChannel="Nav" condDensity="23.4 mS_per_cm2" erev="50mV" segmentGroup="dendrite_group" ion="na"/>
#                 <channelDensity id="Nav_axon" ionChannel="Nav" condDensity="17.12 mS_per_cm2" erev="50mV" segmentGroup="axon_group" ion="na"/>
#                 <specificCapacitance value="1.3 uF_per_cm2"/>
#                 <initMembPotential value="-67mV"/>
#             </membraneProperties>
#             <intracellularProperties>
#                 <resistivity value="0.15 kohm_cm"/>
#             </intracellularProperties>
#         </biophysicalProperties>
#     </cell>
# </neuroml>
# <?xml version="1.0" ?>
# <neuroml xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" id="NeuroML_ionChannel">
#     <notes>NeuroML file containing a single passive Channel description</notes>
#     <ionChannel id="leak_chan" type="ionChannelPassive" conductance="1pS"/>
# </neuroml>
# <?xml version="1.0" ?>
# <neuroml xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" id="NeuroML_ionChannel">
#     <notes>NeuroML file containing a single ion channel</notes>
#     <ionChannel id="HCNolm" species="h" type="ionChannelHH" conductance="1pS">
#         <notes>Hyperpolarization-activated, CN-gated h channel description (from Lawrence 2006)</notes>
#         <gateHHtauInf id="r" instances="1">
#             <timeCourse type="Bezaire_HCNolm_tau"/>
#             <steadyState type="HHSigmoidVariable" rate="1." midpoint="-84.1mV" scale="-10.2mV"/>
#         </gateHHtauInf>
#     </ionChannel>
#     <ComponentType name="Bezaire_HCNolm_tau" extends="baseVoltageDepTime" description="Tau parameter to describe HCNolm">
#         <Constant name="TIME_SCALE" dimension="time" value="1 ms"/>
#         <Constant name="VOLT_SCALE" dimension="voltage" value="1 mV"/>
#         <Dynamics>
#             <DerivedVariable name="V" dimension="none" value="v / VOLT_SCALE"/>
#             <DerivedVariable name="t" dimension="time" exposure="t" value="( 100 + (1 / (exp(-17.9 - 0.116*V) + exp(-1.84 + 0.09*V))) ) * TIME_SCALE"/>
#         </Dynamics>
#     </ComponentType>
# </neuroml>
# <?xml version="1.0" ?>
# <neuroml xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" id="NeuroML_ionChannel">
#     <notes>NeuroML file containing a single ion channel</notes>
#     <ionChannel id="Kdrfast" species="k" type="ionChannelHH" conductance="1pS">
#         <notes>Fast delayed rectifier K+ channel description (from Yuen and Durand 1991, modeled by Marianne Bezaire)</notes>
#         <gateHHrates id="n" instances="4">
#             <q10Settings type="q10ExpTemp" q10Factor="3" experimentalTemp="34 degC"/>
#             <forwardRate type="HHExpLinearRate" rate="0.42per_ms" midpoint="-18mV" scale="6mV"/>
#             <reverseRate type="Bezaire_Kdrfast_betaq"/>
#         </gateHHrates>
#     </ionChannel>
#     <ComponentType name="Bezaire_Kdrfast_betaq" extends="baseVoltageDepRate" description="reverse rate to describe Kdrfast">
#         <Constant name="TIME_SCALE" dimension="time" value="1 ms"/>
#         <Constant name="VOLT_SCALE" dimension="voltage" value="1 mV"/>
#         <Dynamics>
#             <DerivedVariable name="V" dimension="none" value="v / VOLT_SCALE"/>
#             <DerivedVariable name="r" dimension="per_time" exposure="r" value="((0.264) / (exp((V+43)/40))) / TIME_SCALE"/>
#         </Dynamics>
#     </ComponentType>
# </neuroml>
# <?xml version="1.0" ?>
# <neuroml xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" id="NeuroML_ionChannel">
#     <notes>NeuroML file containing a single ion channel</notes>
#     <ionChannel id="KvAolm" species="k" type="ionChannelHH" conductance="1pS">
#         <notes>A-type K+ channel description (from Zhang and McBain 1995, Martina 1998, Warman 1994 - modeled by Marianne Bezaire)</notes>
#         <gateHHtauInf id="a" instances="1">
#             <timeCourse type="fixedTimeCourse" tau="5ms"/>
#             <steadyState type="HHSigmoidVariable" rate="1." midpoint="-14mV" scale="16.6mV"/>
#         </gateHHtauInf>
#         <gateHHtauInf id="b" instances="1">
#             <timeCourse type="Bezaire_KvAolm_taub"/>
#             <steadyState type="HHSigmoidVariable" rate="1." midpoint="-71mV" scale="-7.3mV"/>
#         </gateHHtauInf>
#     </ionChannel>
#     <ComponentType name="Bezaire_KvAolm_taub" extends="baseVoltageDepTime" description="Tau parameter to describe KvAolm">
#         <Constant name="TIME_SCALE" dimension="time" value="1 ms"/>
#         <Constant name="VOLT_SCALE" dimension="voltage" value="1 mV"/>
#         <Dynamics>
#             <DerivedVariable name="V" dimension="none" value="v / VOLT_SCALE"/>
#             <DerivedVariable name="alpha" dimension="none" value="0.000009 / exp((V-26)/18.5)"/>
#             <DerivedVariable name="beta" dimension="none" value="0.014 / (exp((V+70)/-11) + 0.2)"/>
#             <DerivedVariable name="t" dimension="time" exposure="t" value="( 1 / (alpha + beta) ) * TIME_SCALE"/>
#         </Dynamics>
#     </ComponentType>
# </neuroml>
# <?xml version="1.0" ?>
# <neuroml xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" id="NeuroML_ionChannel">
#     <notes>NeuroML file containing a single ion channel</notes>
#     <ionChannel id="Nav" species="na" type="ionChannelHH" conductance="1pS">
#         <notes>Na+ channel description (modeled by Marianne Bezaire)</notes>
#         <gateHHrates id="m" instances="3">
#             <q10Settings type="q10ExpTemp" q10Factor="3" experimentalTemp="34 degC"/>
#             <forwardRate type="HHExpLinearRate" rate="1.5per_ms" midpoint="-43mV" scale="5mV"/>
#             <reverseRate type="HHExpLinearRate" rate="1.5per_ms" midpoint="-15mV" scale="-5mV"/>
#         </gateHHrates>
#         <gateHHrates id="h" instances="1">
#             <q10Settings type="q10ExpTemp" q10Factor="3" experimentalTemp="34 degC"/>
#             <forwardRate type="Bezaire_Nav_alphah"/>
#             <reverseRate type="HHSigmoidRate" rate="3.33per_ms" midpoint="-12.5mV" scale="10mV"/>
#         </gateHHrates>
#     </ionChannel>
#     <ComponentType name="Bezaire_Nav_alphah" extends="baseVoltageDepRate" description="forward rate to describe Nav">
#         <Constant name="TIME_SCALE" dimension="time" value="1 ms"/>
#         <Constant name="VOLT_SCALE" dimension="voltage" value="1 mV"/>
#         <Dynamics>
#             <DerivedVariable name="V" dimension="none" value="v / VOLT_SCALE"/>
#             <DerivedVariable name="r" dimension="per_time" exposure="r" value="( 0.23 / (exp((V+65)/20))) / TIME_SCALE"/>
#         </Dynamics>
#     </ComponentType>
# </neuroml>
# create output columns
# simulation saved
# pyNeuroML >>> CRITICAL - *** Problem running command:
#        Command 'java -Xmx2G  -Djava.awt.headless=true -jar  "/Users/shayan/opt/anaconda3/lib/python3.9/site-packages/pyneuroml/lib/jNeuroML-0.11.1-jar-with-dependencies.jar"  "LEMS_olm_example_sim.xml"  -neuron -run -compile -nogui -I ''' returned non-zero exit status 1.
# pyNeuroML >>> CRITICAL -  jNeuroML >>   jNeuroML v0.11.1
#  jNeuroML >>  (INFO) Reading from: /Users/shayan/Desktop/CN/gsoc_cn/olm_multicompartmental/LEMS_olm_example_sim.xml
#  jNeuroML >>  (INFO) Creating NeuronWriter to output files to /Users/shayan/Desktop/CN/gsoc_cn/olm_multicompartmental
#  jNeuroML >>  (INFO) Adding simulation Component(id=olm_example_sim type=Simulation) of network/component: single_olm_cell_network (Type: network)
#  jNeuroML >>  (INFO) Adding population: pop0
#  jNeuroML >>  (INFO) -- Writing to hoc: /Users/shayan/Desktop/CN/gsoc_cn/olm_multicompartmental/olm.hoc
#  jNeuroML >>  (INFO) -- Writing to mod: /Users/shayan/Desktop/CN/gsoc_cn/olm_multicompartmental/leak_chan.mod
#  jNeuroML >>  (INFO) File /Users/shayan/Desktop/CN/gsoc_cn/olm_multicompartmental/leak_chan.mod exists and is identical
#  jNeuroML >>  (INFO) -- Writing to mod: /Users/shayan/Desktop/CN/gsoc_cn/olm_multicompartmental/HCNolm.mod
#  jNeuroML >>  (INFO) File /Users/shayan/Desktop/CN/gsoc_cn/olm_multicompartmental/HCNolm.mod exists and is identical
#  jNeuroML >>  (INFO) -- Writing to mod: /Users/shayan/Desktop/CN/gsoc_cn/olm_multicompartmental/Kdrfast.mod
#  jNeuroML >>  (INFO) File /Users/shayan/Desktop/CN/gsoc_cn/olm_multicompartmental/Kdrfast.mod exists and is identical
#  jNeuroML >>  (INFO) -- Writing to mod: /Users/shayan/Desktop/CN/gsoc_cn/olm_multicompartmental/KvAolm.mod
#  jNeuroML >>  (INFO) File /Users/shayan/Desktop/CN/gsoc_cn/olm_multicompartmental/KvAolm.mod exists and is identical
#  jNeuroML >>  (INFO) -- Writing to mod: /Users/shayan/Desktop/CN/gsoc_cn/olm_multicompartmental/Nav.mod
#  jNeuroML >>  (INFO) File /Users/shayan/Desktop/CN/gsoc_cn/olm_multicompartmental/Nav.mod exists and is identical
#  jNeuroML >>  (INFO) Adding projections/connections...
#  jNeuroML >>  (INFO) -- Writing to mod: /Users/shayan/Desktop/CN/gsoc_cn/olm_multicompartmental/pg_olm.mod
#  jNeuroML >>  (INFO) File /Users/shayan/Desktop/CN/gsoc_cn/olm_multicompartmental/pg_olm.mod exists and is identical
#  jNeuroML >>  (INFO) Trying to compile mods in: /Users/shayan/Desktop/CN/gsoc_cn/olm_multicompartmental
#  jNeuroML >>  (INFO) Going to compile the mod files in: /Users/shayan/Desktop/CN/gsoc_cn/olm_multicompartmental, forcing recompile: false
#  jNeuroML >>  org.neuroml.model.util.NeuroMLException: Could not find NEURON home directory! Options tried: [/Applications/NEURON-7.5/nrn/powerpc, /Applications/NEURON-7.5/nrn/umac, /Applications/NEURON-7.5/nrn/i386, /Applications/NEURON-7.5/nrn/x86_64, /Applications/NEURON-7.4/nrn/powerpc, /Applications/NEURON-7.4/nrn/umac, /Applications/NEURON-7.4/nrn/i386, /Applications/NEURON-7.4/nrn/x86_64, /Applications/NEURON-7.3/nrn/powerpc, /Applications/NEURON-7.3/nrn/umac, /Applications/NEURON-7.3/nrn/i386, /Applications/NEURON-7.3/nrn/x86_64, /Applications/NEURON-7.2/nrn/powerpc, /Applications/NEURON-7.2/nrn/umac, /Applications/NEURON-7.2/nrn/i386, /Applications/NEURON-7.2/nrn/x86_64, /Applications/NEURON-7.1/nrn/powerpc, /Applications/NEURON-7.1/nrn/umac, /Applications/NEURON-7.1/nrn/i386, /Applications/NEURON-7.1/nrn/x86_64, /Applications/NEURON-6.2/nrn/powerpc, /Applications/NEURON-6.2/nrn/umac, /Applications/NEURON-6.2/nrn/i386, /Applications/NEURON-6.2/nrn/x86_64, /Applications/NEURON-6.1/nrn/powerpc, /Applications/NEURON-6.1/nrn/umac, /Applications/NEURON-6.1/nrn/i386, /Applications/NEURON-6.1/nrn/x86_64, /Applications/NEURON-6.0/nrn/powerpc, /Applications/NEURON-6.0/nrn/umac, /Applications/NEURON-6.0/nrn/i386, /Applications/NEURON-6.0/nrn/x86_64]
#  jNeuroML >>  The NEURON executable which is sought inside this directory is: bin/nrniv.
#  jNeuroML >>
#  jNeuroML >>  Try setting the environment variable NEURON_HOME to the location of your NEURON installation (up to but not including bin), e.g.
#  jNeuroML >>
#  jNeuroML >>    export NEURON_HOME=/home/myuser/nrn7/x86_64
#  jNeuroML >>
#  jNeuroML >>  Currently NEURON_HOME is set to: null
#  jNeuroML >>    Environment variables:
#  jNeuroML >>      _                               = /usr/bin/java
#  jNeuroML >>      __CF_USER_TEXT_ENCODING         = 0x1F5:0x0:0x0
#  jNeuroML >>      __CFBundleIdentifier            = com.apple.Terminal
#  jNeuroML >>      _CE_CONDA                       =
#  jNeuroML >>      _CE_M                           =
#  jNeuroML >>      CLICOLOR                        = 1
#  jNeuroML >>      CONDA_DEFAULT_ENV               = base
#  jNeuroML >>      CONDA_EXE                       = /Users/shayan/opt/anaconda3/bin/conda
#  jNeuroML >>      CONDA_PREFIX                    = /Users/shayan/opt/anaconda3
#  jNeuroML >>      CONDA_PROMPT_MODIFIER           = (base)
#  jNeuroML >>      CONDA_PYTHON_EXE                = /Users/shayan/opt/anaconda3/bin/python
#  jNeuroML >>      CONDA_SHLVL                     = 1
#  jNeuroML >>      DISPLAY                         = /private/tmp/com.apple.launchd.x1ecCYIvcf/org.xquartz:0
#  jNeuroML >>      GIT_PAGER                       = cat
#  jNeuroML >>      HOME                            = /Users/shayan
#  jNeuroML >>      HOMEBREW_CELLAR                 = /opt/homebrew/Cellar
#  jNeuroML >>      HOMEBREW_PREFIX                 = /opt/homebrew
#  jNeuroML >>      HOMEBREW_REPOSITORY             = /opt/homebrew
#  jNeuroML >>      INFOPATH                        = /opt/homebrew/share/info:
#  jNeuroML >>      JAVA_MAIN_CLASS_2760            = org.neuroml.JNeuroML
#  jNeuroML >>      JPY_PARENT_PID                  = 2416
#  jNeuroML >>      LaunchInstanceID                = E184FB42-64E4-413E-ACBE-3F8E3FCACEA9
#  jNeuroML >>      LC_CTYPE                        = UTF-8
#  jNeuroML >>      LOGNAME                         = shayan
#  jNeuroML >>      MANPATH                         = /opt/homebrew/share/man::
#  jNeuroML >>      MPLBACKEND                      = module://matplotlib_inline.backend_inline
#  jNeuroML >>      PAGER                           = cat
#  jNeuroML >>      PATH                            = /Applications/NEURON/bin:/Applications/NEURON/bin:/Applications/NEURON/bin:/Users/shayan/opt/anaconda3/bin:/Users/shayan/opt/anaconda3/condabin:/opt/homebrew/bin:/opt/homebrew/sbin:/usr/local/bin:/usr/bin:/bin:/usr/sbin:/sbin:/opt/X11/bin
#  jNeuroML >>      PWD                             = /Users/shayan/Desktop/CN/gsoc_cn/olm_multicompartmental
#  jNeuroML >>      PYDEVD_USE_FRAME_EVAL           = NO
#  jNeuroML >>      PYENV_SHELL                     = zsh
#  jNeuroML >>      PYTHONPATH                      = /Users/shayan/.ipython:/Users/shayan/opt/anaconda3/lib/python3.9/site-packages/IPython/extensions:/Users/shayan/opt/anaconda3/lib/python3.9/site-packages/locket-0.2.1-py3.9.egg:/Users/shayan/opt/anaconda3/lib/python3.9/site-packages/aeosa:/Users/shayan/opt/anaconda3/lib/python3.9/site-packages:/Users/shayan/.local/lib/python3.9/site-packages:/Users/shayan/opt/anaconda3/lib/python3.9/lib-dynload:/Users/shayan/opt/anaconda3/lib/python3.9:/Users/shayan/opt/anaconda3/lib/python39.zip:/Users/shayan/Desktop/CN/gsoc_cn/olm_multicompartmental:/Applications/NEURON/lib/python:/Applications/NEURON/lib/python:/Applications/NEURON/lib/python:
#  jNeuroML >>      SECURITYSESSIONID               = 186b2
#  jNeuroML >>      SHELL                           = /bin/zsh
#  jNeuroML >>      SHLVL                           = 3
#  jNeuroML >>      SSH_AUTH_SOCK                   = /private/tmp/com.apple.launchd.WMq3KkK1LX/Listeners
#  jNeuroML >>      TERM                            = xterm-color
#  jNeuroML >>      TERM_PROGRAM                    = Apple_Terminal
#  jNeuroML >>      TERM_PROGRAM_VERSION            = 443
#  jNeuroML >>      TERM_SESSION_ID                 = A4C8F256-AD45-4F8B-95DA-2A16FBD03179
#  jNeuroML >>      TMPDIR                          = /var/folders/fp/j9ldfbxj2_gflf_hz4bf_wyc0000gn/T/
#  jNeuroML >>      USER                            = shayan
#  jNeuroML >>      XPC_FLAGS                       = 0x0
#  jNeuroML >>      XPC_SERVICE_NAME                = 0
#  jNeuroML >>
#  jNeuroML >>  	at org.neuroml.export.neuron.ProcessManager.findNeuronHome(ProcessManager.java:87)
#  jNeuroML >>  	at org.neuroml.export.neuron.ProcessManager.compileFileWithNeuron(ProcessManager.java:107)
#  jNeuroML >>  	at org.neuroml.export.neuron.NeuronWriter.generateAndRun(NeuronWriter.java:163)
#  jNeuroML >>  	at org.neuroml.JNeuroML.main(JNeuroML.java:517)
#  jNeuroML >>
# pyNeuroML >>> ERROR - execute_command_in_dir returned with output:  jNeuroML v0.11.1
# (INFO) Reading from: /Users/shayan/Desktop/CN/gsoc_cn/olm_multicompartmental/LEMS_olm_example_sim.xml
# (INFO) Creating NeuronWriter to output files to /Users/shayan/Desktop/CN/gsoc_cn/olm_multicompartmental
# (INFO) Adding simulation Component(id=olm_example_sim type=Simulation) of network/component: single_olm_cell_network (Type: network)
# (INFO) Adding population: pop0
# (INFO) -- Writing to hoc: /Users/shayan/Desktop/CN/gsoc_cn/olm_multicompartmental/olm.hoc
# (INFO) -- Writing to mod: /Users/shayan/Desktop/CN/gsoc_cn/olm_multicompartmental/leak_chan.mod
# (INFO) File /Users/shayan/Desktop/CN/gsoc_cn/olm_multicompartmental/leak_chan.mod exists and is identical
# (INFO) -- Writing to mod: /Users/shayan/Desktop/CN/gsoc_cn/olm_multicompartmental/HCNolm.mod
# (INFO) File /Users/shayan/Desktop/CN/gsoc_cn/olm_multicompartmental/HCNolm.mod exists and is identical
# (INFO) -- Writing to mod: /Users/shayan/Desktop/CN/gsoc_cn/olm_multicompartmental/Kdrfast.mod
# (INFO) File /Users/shayan/Desktop/CN/gsoc_cn/olm_multicompartmental/Kdrfast.mod exists and is identical
# (INFO) -- Writing to mod: /Users/shayan/Desktop/CN/gsoc_cn/olm_multicompartmental/KvAolm.mod
# (INFO) File /Users/shayan/Desktop/CN/gsoc_cn/olm_multicompartmental/KvAolm.mod exists and is identical
# (INFO) -- Writing to mod: /Users/shayan/Desktop/CN/gsoc_cn/olm_multicompartmental/Nav.mod
# (INFO) File /Users/shayan/Desktop/CN/gsoc_cn/olm_multicompartmental/Nav.mod exists and is identical
# (INFO) Adding projections/connections...
# (INFO) -- Writing to mod: /Users/shayan/Desktop/CN/gsoc_cn/olm_multicompartmental/pg_olm.mod
# (INFO) File /Users/shayan/Desktop/CN/gsoc_cn/olm_multicompartmental/pg_olm.mod exists and is identical
# (INFO) Trying to compile mods in: /Users/shayan/Desktop/CN/gsoc_cn/olm_multicompartmental
# (INFO) Going to compile the mod files in: /Users/shayan/Desktop/CN/gsoc_cn/olm_multicompartmental, forcing recompile: false
# org.neuroml.model.util.NeuroMLException: Could not find NEURON home directory! Options tried: [/Applications/NEURON-7.5/nrn/powerpc, /Applications/NEURON-7.5/nrn/umac, /Applications/NEURON-7.5/nrn/i386, /Applications/NEURON-7.5/nrn/x86_64, /Applications/NEURON-7.4/nrn/powerpc, /Applications/NEURON-7.4/nrn/umac, /Applications/NEURON-7.4/nrn/i386, /Applications/NEURON-7.4/nrn/x86_64, /Applications/NEURON-7.3/nrn/powerpc, /Applications/NEURON-7.3/nrn/umac, /Applications/NEURON-7.3/nrn/i386, /Applications/NEURON-7.3/nrn/x86_64, /Applications/NEURON-7.2/nrn/powerpc, /Applications/NEURON-7.2/nrn/umac, /Applications/NEURON-7.2/nrn/i386, /Applications/NEURON-7.2/nrn/x86_64, /Applications/NEURON-7.1/nrn/powerpc, /Applications/NEURON-7.1/nrn/umac, /Applications/NEURON-7.1/nrn/i386, /Applications/NEURON-7.1/nrn/x86_64, /Applications/NEURON-6.2/nrn/powerpc, /Applications/NEURON-6.2/nrn/umac, /Applications/NEURON-6.2/nrn/i386, /Applications/NEURON-6.2/nrn/x86_64, /Applications/NEURON-6.1/nrn/powerpc, /Applications/NEURON-6.1/nrn/umac, /Applications/NEURON-6.1/nrn/i386, /Applications/NEURON-6.1/nrn/x86_64, /Applications/NEURON-6.0/nrn/powerpc, /Applications/NEURON-6.0/nrn/umac, /Applications/NEURON-6.0/nrn/i386, /Applications/NEURON-6.0/nrn/x86_64]
# The NEURON executable which is sought inside this directory is: bin/nrniv.
#
# Try setting the environment variable NEURON_HOME to the location of your NEURON installation (up to but not including bin), e.g.
#
#   export NEURON_HOME=/home/myuser/nrn7/x86_64
#
# Currently NEURON_HOME is set to: null
#   Environment variables:
#     _                               = /usr/bin/java
#     __CF_USER_TEXT_ENCODING         = 0x1F5:0x0:0x0
#     __CFBundleIdentifier            = com.apple.Terminal
#     _CE_CONDA                       =
#     _CE_M                           =
#     CLICOLOR                        = 1
#     CONDA_DEFAULT_ENV               = base
#     CONDA_EXE                       = /Users/shayan/opt/anaconda3/bin/conda
#     CONDA_PREFIX                    = /Users/shayan/opt/anaconda3
#     CONDA_PROMPT_MODIFIER           = (base)
#     CONDA_PYTHON_EXE                = /Users/shayan/opt/anaconda3/bin/python
#     CONDA_SHLVL                     = 1
#     DISPLAY                         = /private/tmp/com.apple.launchd.x1ecCYIvcf/org.xquartz:0
#     GIT_PAGER                       = cat
#     HOME                            = /Users/shayan
#     HOMEBREW_CELLAR                 = /opt/homebrew/Cellar
#     HOMEBREW_PREFIX                 = /opt/homebrew
#     HOMEBREW_REPOSITORY             = /opt/homebrew
#     INFOPATH                        = /opt/homebrew/share/info:
#     JAVA_MAIN_CLASS_2760            = org.neuroml.JNeuroML
#     JPY_PARENT_PID                  = 2416
#     LaunchInstanceID                = E184FB42-64E4-413E-ACBE-3F8E3FCACEA9
#     LC_CTYPE                        = UTF-8
#     LOGNAME                         = shayan
#     MANPATH                         = /opt/homebrew/share/man::
#     MPLBACKEND                      = module://matplotlib_inline.backend_inline
#     PAGER                           = cat
#     PATH                            = /Applications/NEURON/bin:/Applications/NEURON/bin:/Applications/NEURON/bin:/Users/shayan/opt/anaconda3/bin:/Users/shayan/opt/anaconda3/condabin:/opt/homebrew/bin:/opt/homebrew/sbin:/usr/local/bin:/usr/bin:/bin:/usr/sbin:/sbin:/opt/X11/bin
#     PWD                             = /Users/shayan/Desktop/CN/gsoc_cn/olm_multicompartmental
#     PYDEVD_USE_FRAME_EVAL           = NO
#     PYENV_SHELL                     = zsh
#     PYTHONPATH                      = /Users/shayan/.ipython:/Users/shayan/opt/anaconda3/lib/python3.9/site-packages/IPython/extensions:/Users/shayan/opt/anaconda3/lib/python3.9/site-packages/locket-0.2.1-py3.9.egg:/Users/shayan/opt/anaconda3/lib/python3.9/site-packages/aeosa:/Users/shayan/opt/anaconda3/lib/python3.9/site-packages:/Users/shayan/.local/lib/python3.9/site-packages:/Users/shayan/opt/anaconda3/lib/python3.9/lib-dynload:/Users/shayan/opt/anaconda3/lib/python3.9:/Users/shayan/opt/anaconda3/lib/python39.zip:/Users/shayan/Desktop/CN/gsoc_cn/olm_multicompartmental:/Applications/NEURON/lib/python:/Applications/NEURON/lib/python:/Applications/NEURON/lib/python:
#     SECURITYSESSIONID               = 186b2
#     SHELL                           = /bin/zsh
#     SHLVL                           = 3
#     SSH_AUTH_SOCK                   = /private/tmp/com.apple.launchd.WMq3KkK1LX/Listeners
#     TERM                            = xterm-color
#     TERM_PROGRAM                    = Apple_Terminal
#     TERM_PROGRAM_VERSION            = 443
#     TERM_SESSION_ID                 = A4C8F256-AD45-4F8B-95DA-2A16FBD03179
#     TMPDIR                          = /var/folders/fp/j9ldfbxj2_gflf_hz4bf_wyc0000gn/T/
#     USER                            = shayan
#     XPC_FLAGS                       = 0x0
#     XPC_SERVICE_NAME                = 0
#
# 	at org.neuroml.export.neuron.ProcessManager.findNeuronHome(ProcessManager.java:87)
# 	at org.neuroml.export.neuron.ProcessManager.compileFileWithNeuron(ProcessManager.java:107)
# 	at org.neuroml.export.neuron.NeuronWriter.generateAndRun(NeuronWriter.java:163)
# 	at org.neuroml.JNeuroML.main(JNeuroML.java:517)
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# /Users/shayan/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3452: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# Simulation bits
sim_id = "olm_example_sim"
simulation = LEMSSimulation(sim_id=sim_id, duration=600, dt=0.01, simulation_seed=123)
# Include the NeuroML model file
simulation.include_neuroml2_file(create_olm_network())
# Assign target for the simulation
# simulation.assign_simulation_target("single_olm_cell_network")
print("create output columns")
# Recording information from the simulation
# simulation.create_output_file(id="output0", file_name=sim_id + ".dat")
# simulation.add_column_to_output_file("output0", column_id="pop0_0_v", quantity="pop0[0]/v")
# simulation.add_column_to_output_file("output0",
#                                      column_id="pop0_0_v_Seg0_soma_0",
#                                      quantity="pop0/0/olm/0/v")
# simulation.add_column_to_output_file("output0",
#                                      column_id="pop0_0_v_Seg1_soma_0",
#                                      quantity="pop0/0/olm/1/v")
# simulation.add_column_to_output_file("output0",
#                                      column_id="pop0_0_v_Seg0_axon_0",
#                                      quantity="pop0/0/olm/2/v")
# simulation.add_column_to_output_file("output0",
#                                      column_id="pop0_0_v_Seg1_axon_0",
#                                      quantity="pop0/0/olm/3/v")
# simulation.add_column_to_output_file("output0",
#                                      column_id="pop0_0_v_Seg0_dend_0",
#                                      quantity="pop0/0/olm/4/v")
# simulation.add_column_to_output_file("output0",
#                                      column_id="pop0_0_v_Seg1_dend_0",
#                                      quantity="pop0/0/olm/6/v")
# simulation.add_column_to_output_file("output0",
#                                      column_id="pop0_0_v_Seg0_dend_1",
#                                      quantity="pop0/0/olm/5/v")
# simulation.add_column_to_output_file("output0",
#                                      column_id="pop0_0_v_Seg1_dend_1",
#                                      quantity="pop0/0/olm/7/v")
# # Save LEMS simulation to file
# sim_file = simulation.save_to_file()
# print("simulation saved")
# # Run the simulation using the NEURON simulator
# pynml.run_lems_with_jneuroml_neuron(sim_file, max_memory="2G", nogui=True,
#                                     plot=False, skip_run=False)
# Out:
# pyNeuroML >>> INFO - Executing: (java -Xmx400M  -jar  "/Users/shayan/opt/anaconda3/lib/python3.9/site-packages/pyneuroml/lib/jNeuroML-0.11.1-jar-with-dependencies.jar" -validate "olm.cell.nml" ) in directory: .
# pyNeuroML >>> CRITICAL - *** Problem running command:
#        Command 'java -Xmx400M  -jar  "/Users/shayan/opt/anaconda3/lib/python3.9/site-packages/pyneuroml/lib/jNeuroML-0.11.1-jar-with-dependencies.jar" -validate "olm.cell.nml" ' returned non-zero exit status 1.
# pyNeuroML >>> CRITICAL -  jNeuroML >>   jNeuroML v0.11.1
#  jNeuroML >>  Validating: /Users/shayan/Desktop/CN/gsoc_cn/olm_multicompartmental/olm.cell.nml
#  jNeuroML >>  Valid against schema
#  jNeuroML >>    Test: 10025 (Ion channel in channelDensity should exist) failed! ... Ion channel: leak_chan in leak_all not found!
#  jNeuroML >>    Test: 10025 (Ion channel in channelDensity should exist) failed! ... Ion channel: HCNolm in HCNolm_soma not found!
#  jNeuroML >>    Test: 10025 (Ion channel in channelDensity should exist) failed! ... Ion channel: Kdrfast in Kdrfast_soma not found!
#  jNeuroML >>    Test: 10025 (Ion channel in channelDensity should exist) failed! ... Ion channel: Kdrfast in Kdrfast_dendrite not found!
#  jNeuroML >>    Test: 10025 (Ion channel in channelDensity should exist) failed! ... Ion channel: Kdrfast in Kdrfast_axon not found!
#  jNeuroML >>    Test: 10025 (Ion channel in channelDensity should exist) failed! ... Ion channel: KvAolm in KvAolm_soma not found!
#  jNeuroML >>    Test: 10025 (Ion channel in channelDensity should exist) failed! ... Ion channel: KvAolm in KvAolm_dendrite not found!
#  jNeuroML >>    Test: 10025 (Ion channel in channelDensity should exist) failed! ... Ion channel: Nav in Nav_soma not found!
#  jNeuroML >>    Test: 10025 (Ion channel in channelDensity should exist) failed! ... Ion channel: Nav in Nav_dendrite not found!
#  jNeuroML >>    Test: 10025 (Ion channel in channelDensity should exist) failed! ... Ion channel: Nav in Nav_axon not found!
#  jNeuroML >>
#  jNeuroML >>    Warning, check: 100005 (Segment Group used in the include element of segmentGroup should probably be defined BEFORE it is used in the segmentGroup in which it is included, for optimal portability) failed! ... SegmentGroup: soma_group, includes: soma_0
#  jNeuroML >>    Warning, check: 100005 (Segment Group used in the include element of segmentGroup should probably be defined BEFORE it is used in the segmentGroup in which it is included, for optimal portability) failed! ... SegmentGroup: axon_group, includes: axon_0
#  jNeuroML >>    Warning, check: 100005 (Segment Group used in the include element of segmentGroup should probably be defined BEFORE it is used in the segmentGroup in which it is included, for optimal portability) failed! ... SegmentGroup: dendrite_group, includes: dend_0
#  jNeuroML >>    Warning, check: 100005 (Segment Group used in the include element of segmentGroup should probably be defined BEFORE it is used in the segmentGroup in which it is included, for optimal portability) failed! ... SegmentGroup: dendrite_group, includes: dend_1
#  jNeuroML >>
#  jNeuroML >>  Validated 1 files: 0 passed, 1 failed
#  jNeuroML >>
#  jNeuroML >>
# pyNeuroML >>> INFO - Executing: (java -Xmx400M  -jar  "/Users/shayan/opt/anaconda3/lib/python3.9/site-packages/pyneuroml/lib/jNeuroML-0.11.1-jar-with-dependencies.jar" -validate "olm_example_net.nml" ) in directory: .
# pyNeuroML >>> CRITICAL - *** Problem running command:
#        Command 'java -Xmx400M  -jar  "/Users/shayan/opt/anaconda3/lib/python3.9/site-packages/pyneuroml/lib/jNeuroML-0.11.1-jar-with-dependencies.jar" -validate "olm_example_net.nml" ' returned non-zero exit status 1.
# pyNeuroML >>> CRITICAL -  jNeuroML >>   jNeuroML v0.11.1
#  jNeuroML >>  Validating: /Users/shayan/Desktop/CN/gsoc_cn/olm_multicompartmental/olm_example_net.nml
#  jNeuroML >>  Valid against schema
#  jNeuroML >>    Test: 10025 (Ion channel in channelDensity should exist) failed! ... Ion channel: leak_chan in leak_all not found!
#  jNeuroML >>    Test: 10025 (Ion channel in channelDensity should exist) failed! ... Ion channel: HCNolm in HCNolm_soma not found!
#  jNeuroML >>    Test: 10025 (Ion channel in channelDensity should exist) failed! ... Ion channel: Kdrfast in Kdrfast_soma not found!
#  jNeuroML >>    Test: 10025 (Ion channel in channelDensity should exist) failed! ... Ion channel: Kdrfast in Kdrfast_dendrite not found!
#  jNeuroML >>    Test: 10025 (Ion channel in channelDensity should exist) failed! ... Ion channel: Kdrfast in Kdrfast_axon not found!
#  jNeuroML >>    Test: 10025 (Ion channel in channelDensity should exist) failed! ... Ion channel: KvAolm in KvAolm_soma not found!
#  jNeuroML >>    Test: 10025 (Ion channel in channelDensity should exist) failed! ... Ion channel: KvAolm in KvAolm_dendrite not found!
#  jNeuroML >>    Test: 10025 (Ion channel in channelDensity should exist) failed! ... Ion channel: Nav in Nav_soma not found!
#  jNeuroML >>    Test: 10025 (Ion channel in channelDensity should exist) failed! ... Ion channel: Nav in Nav_dendrite not found!
#  jNeuroML >>    Test: 10025 (Ion channel in channelDensity should exist) failed! ... Ion channel: Nav in Nav_axon not found!
#  jNeuroML >>
#  jNeuroML >>    Warning, check: 100005 (Segment Group used in the include element of segmentGroup should probably be defined BEFORE it is used in the segmentGroup in which it is included, for optimal portability) failed! ... SegmentGroup: soma_group, includes: soma_0
#  jNeuroML >>    Warning, check: 100005 (Segment Group used in the include element of segmentGroup should probably be defined BEFORE it is used in the segmentGroup in which it is included, for optimal portability) failed! ... SegmentGroup: axon_group, includes: axon_0
#  jNeuroML >>    Warning, check: 100005 (Segment Group used in the include element of segmentGroup should probably be defined BEFORE it is used in the segmentGroup in which it is included, for optimal portability) failed! ... SegmentGroup: dendrite_group, includes: dend_0
#  jNeuroML >>    Warning, check: 100005 (Segment Group used in the include element of segmentGroup should probably be defined BEFORE it is used in the segmentGroup in which it is included, for optimal portability) failed! ... SegmentGroup: dendrite_group, includes: dend_1
#  jNeuroML >>
#  jNeuroML >>  Validated 1 files: 0 passed, 1 failed
#  jNeuroML >>
#  jNeuroML >>
# pyNeuroML >>> INFO - Loading NeuroML2 file: /Users/shayan/Desktop/CN/gsoc_cn/olm_multicompartmental/olm_example_net.nml
# pyNeuroML >>> INFO - Loading NeuroML2 file: /Users/shayan/Desktop/CN/gsoc_cn/olm_multicompartmental/olm.cell.nml
# pyNeuroML >>> INFO - Loading NeuroML2 file: /Users/shayan/Desktop/CN/gsoc_cn/olm_multicompartmental/olm-example/leak_chan.channel.nml
# pyNeuroML >>> CRITICAL - Unable to find file: /Users/shayan/Desktop/CN/gsoc_cn/olm_multicompartmental/olm-example/leak_chan.channel.nml!
# <?xml version="1.0" ?>
# <neuroml xmlns:xs="http://www.w3.org/2001/XMLSchema" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" id="network">
#     <notes>OLM cell network</notes>
#     <include href="olm.cell.nml"/>
#     <pulseGenerator id="pg_olm" delay="100ms" duration="100ms" amplitude="0.08nA">
#         <notes>Simple pulse generator</notes>
#     </pulseGenerator>
#     <network id="single_olm_cell_network">
#         <population id="pop0" component="olm" size="1" type="populationList">
#             <notes>A population for our cell</notes>
#             <instance id="1">
#                 <location x="0." y="0." z="0."/>
#             </instance>
#         </population>
#         <explicitInput target="pop0[0]" input="pg_olm"/>
#     </network>
# </neuroml>
# <?xml version="1.0" ?>
# <neuroml xmlns:xs="http://www.w3.org/2001/XMLSchema" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" id="oml_cell">
#     <include href="olm-example/leak_chan.channel.nml"/>
#     <include href="olm-example/HCNolm.channel.nml"/>
#     <include href="olm-example/Kdrfast.channel.nml"/>
#     <include href="olm-example/KvAolm.channel.nml"/>
#     <include href="olm-example/Nav.channel.nml"/>
#     <cell id="olm">
#         <morphology id="morphology">
#             <segment id="0" name="Seg0_soma_0">
#                 <proximal x="0.0" y="0.0" z="0.0" diameter="10.0"/>
#                 <distal x="0.0" y="10.0" z="0.0" diameter="10.0"/>
#             </segment>
#             <segment id="1" name="Seg1_soma_0">
#                 <parent segment="0"/>
#                 <distal x="0.0" y="20.0" z="0.0" diameter="10.0"/>
#             </segment>
#             <segment id="2" name="Seg0_axon_0">
#                 <parent segment="0" fractionAlong="0."/>
#                 <proximal x="0.0" y="0.0" z="0.0" diameter="1.5"/>
#                 <distal x="0.0" y="-75.0" z="0.0" diameter="1.5"/>
#             </segment>
#             <segment id="3" name="Seg1_axon_0">
#                 <parent segment="2"/>
#                 <distal x="0.0" y="-150.0" z="0.0" diameter="1.5"/>
#             </segment>
#             <segment id="4" name="Seg0_dend_0">
#                 <parent segment="1"/>
#                 <proximal x="0.0" y="20.0" z="0.0" diameter="3.0"/>
#                 <distal x="100.0" y="120.0" z="0.0" diameter="3.0"/>
#             </segment>
#             <segment id="5" name="Seg1_dend_0">
#                 <parent segment="4"/>
#                 <distal x="177.0" y="197.0" z="0.0" diameter="3.0"/>
#             </segment>
#             <segment id="6" name="Seg0_dend_1">
#                 <parent segment="1"/>
#                 <proximal x="0.0" y="20.0" z="0.0" diameter="3.0"/>
#                 <distal x="-100.0" y="120.0" z="0.0" diameter="3.0"/>
#             </segment>
#             <segment id="7" name="Seg1_dend_1">
#                 <parent segment="6"/>
#                 <distal x="-177.0" y="197.0" z="0.0" diameter="3.0"/>
#             </segment>
#             <segmentGroup id="all">
#                 <member segment="0"/>
#                 <member segment="1"/>
#                 <member segment="2"/>
#                 <member segment="3"/>
#                 <member segment="4"/>
#                 <member segment="5"/>
#                 <member segment="6"/>
#                 <member segment="7"/>
#             </segmentGroup>
#             <segmentGroup neuroLexId="GO:0043025" id="soma_group">
#                 <notes>Default soma segment group for the cell</notes>
#                 <property tag="color" value="0 0 0.8"/>
#                 <member segment="0"/>
#                 <member segment="1"/>
#                 <include segmentGroup="soma_0"/>
#             </segmentGroup>
#             <segmentGroup neuroLexId="GO:0030424" id="axon_group">
#                 <notes>Default axon segment group for the cell</notes>
#                 <property tag="color" value="0 0.8 0"/>
#                 <member segment="2"/>
#                 <member segment="3"/>
#                 <include segmentGroup="axon_0"/>
#             </segmentGroup>
#             <segmentGroup neuroLexId="GO:0030425" id="dendrite_group">
#                 <notes>Default dendrite segment group for the cell</notes>
#                 <property tag="color" value="0.8 0 0"/>
#                 <member segment="4"/>
#                 <member segment="5"/>
#                 <member segment="6"/>
#                 <member segment="7"/>
#                 <include segmentGroup="dend_0"/>
#                 <include segmentGroup="dend_1"/>
#             </segmentGroup>
#             <segmentGroup neuroLexId="sao864921383" id="soma_0">
#                 <member segment="0"/>
#                 <member segment="1"/>
#             </segmentGroup>
#             <segmentGroup neuroLexId="sao864921383" id="axon_0">
#                 <member segment="2"/>
#                 <member segment="3"/>
#             </segmentGroup>
#             <segmentGroup neuroLexId="sao864921383" id="dend_0">
#                 <member segment="4"/>
#                 <member segment="5"/>
#             </segmentGroup>
#             <segmentGroup neuroLexId="sao864921383" id="dend_1">
#                 <member segment="6"/>
#                 <member segment="7"/>
#             </segmentGroup>
#         </morphology>
#         <biophysicalProperties id="biophys">
#             <membraneProperties>
#                 <channelDensity id="leak_all" ionChannel="leak_chan" condDensity="0.01 mS_per_cm2" erev="-67mV" ion="non_specific"/>
#                 <channelDensity id="HCNolm_soma" ionChannel="HCNolm" condDensity="0.5 mS_per_cm2" erev="-32.9mV" segmentGroup="soma_group" ion="h"/>
#                 <channelDensity id="Kdrfast_soma" ionChannel="Kdrfast" condDensity="73.37 mS_per_cm2" erev="-77mV" segmentGroup="soma_group" ion="k"/>
#                 <channelDensity id="Kdrfast_dendrite" ionChannel="Kdrfast" condDensity="105.8 mS_per_cm2" erev="-77mV" segmentGroup="dendrite_group" ion="k"/>
#                 <channelDensity id="Kdrfast_axon" ionChannel="Kdrfast" condDensity="117.392 mS_per_cm2" erev="-77mV" segmentGroup="axon_group" ion="k"/>
#                 <channelDensity id="KvAolm_soma" ionChannel="KvAolm" condDensity="4.95 mS_per_cm2" erev="-77mV" segmentGroup="soma_group" ion="k"/>
#                 <channelDensity id="KvAolm_dendrite" ionChannel="KvAolm" condDensity="2.8 mS_per_cm2" erev="-77mV" segmentGroup="dendrite_group" ion="k"/>
#                 <channelDensity id="Nav_soma" ionChannel="Nav" condDensity="10.7 mS_per_cm2" erev="50mV" segmentGroup="soma_group" ion="na"/>
#                 <channelDensity id="Nav_dendrite" ionChannel="Nav" condDensity="23.4 mS_per_cm2" erev="50mV" segmentGroup="dendrite_group" ion="na"/>
#                 <channelDensity id="Nav_axon" ionChannel="Nav" condDensity="17.12 mS_per_cm2" erev="50mV" segmentGroup="axon_group" ion="na"/>
#                 <specificCapacitance value="1.3 uF_per_cm2"/>
#                 <initMembPotential value="-67mV"/>
#             </membraneProperties>
#             <intracellularProperties>
#                 <resistivity value="0.15 kohm_cm"/>
#             </intracellularProperties>
#         </biophysicalProperties>
#     </cell>
# </neuroml>
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# /Users/shayan/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3452: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
